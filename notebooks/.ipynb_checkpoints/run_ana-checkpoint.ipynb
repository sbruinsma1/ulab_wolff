# %%
import numpy as np
import pandas as pd
import os
import glob
import re
import matplotlib.pyplot as plt
import seaborn as sns
import re
from pathlib import Path
import json 

import warnings
warnings.filterwarnings("ignore")

# load in directories
import mainFunctions
import plotDaily, circadianImgs, arenaTests, phenotyperTests, bdnf
import allFigures
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-cbd70551d2c5> in <module>
#      14
#      15 # load in directories
# ---> 16 import mainFunctions
#      17 import plotDaily, circadianImgs, arenaTests, phenotyperTests, bdnf
#      18 import allFigures
#
# ModuleNotFoundError: No module named 'mainFunctions'

# %%
allFigures.fig2()
# Out:
# 	Updating plotParams from "cogVWRA/plotParams.txt"
# 	Updating plotParams from "cogVWRA/plotParams.txt"
# 	Removing 4 mice...
# 	Updating plotParams from "cogVWRA/plotParams.txt"
# 	Updating plotParams from "cogVWRA/plotParams.txt"
# 	Removing 4 mice...
# Irrad vs Sham: d = 1.78, t = 15.64, p=6.0859e-23, n=32+35
#     shapiro: p = 0.587, 0.668
#
# Y-Maze Distance (m):
# 	Irrad vs Sham: d = 0.72, t = 1.92, p=0.0663, n=13+14
#     shapiro: p = 0.955, 0.109
#
# Arm Entries:
# 	Irrad vs Sham: d = 0.60, t = 1.56, p=0.1320, n=13+14
#     shapiro: p = 0.104, 0.977
#
# Spontaneous Alternation (%):
# 	Irrad vs Sham: d = 0.85, t = 2.34, p=0.0279, n=13+14
#     shapiro: p = 0.605, 0.079
#
# Open Field Distance (m):
# 	Irrad vs Sham: d = 0.16, t = 0.54, p=0.5935, n=23+22
#     shapiro: p = 0.284, 0.128
#
# Center Time (%):
# 	Irrad vs Sham: d = -0.35, t = 1.17, p=0.2472, n=23+22
#     shapiro: p = 0.461, 0.129
# 	Updating plotParams from "cogVWRA/plotParams.txt"
# 	Removing 4 mice...
# ...
