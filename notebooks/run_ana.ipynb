# %%
import numpy as np
import pandas as pd
import os
import glob
import re
import matplotlib.pyplot as plt
import seaborn as sns
import re
from pathlib import Path
import json 
import sys
sys.path.append("/Users/sbruinsma/Desktop/Other Projects/ULAB/ulab_wolff_code")
#use direct path

import warnings
warnings.filterwarnings("ignore")

# load in directories
import mainFunctions, plotDaily, circadianImgs, arenaTests, phenotyperTests, bdnf, allFigures

# %%
allFigures.fig2()
# Out:
# 	Updating plotParams from "cogVWRA/plotParams.txt"
# 	Updating plotParams from "cogVWRA/plotParams.txt"
# 	Removing 4 mice...
# 	Updating plotParams from "cogVWRA/plotParams.txt"
# 	Updating plotParams from "cogVWRA/plotParams.txt"
# 	Removing 4 mice...
# Irrad vs Sham: d = 1.78, t = 15.64, p=6.0859e-23, n=32+35
#     shapiro: p = 0.587, 0.668
#
# Y-Maze Distance (m):
# 	Irrad vs Sham: d = 0.72, t = 1.92, p=0.0663, n=13+14
#     shapiro: p = 0.955, 0.109
#
# Arm Entries:
# 	Irrad vs Sham: d = 0.60, t = 1.56, p=0.1320, n=13+14
#     shapiro: p = 0.104, 0.977
#
# Spontaneous Alternation (%):
# 	Irrad vs Sham: d = 0.85, t = 2.34, p=0.0279, n=13+14
#     shapiro: p = 0.605, 0.079
#
# Open Field Distance (m):
# 	Irrad vs Sham: d = 0.16, t = 0.54, p=0.5935, n=23+22
#     shapiro: p = 0.284, 0.128
#
# Center Time (%):
# 	Irrad vs Sham: d = -0.35, t = 1.17, p=0.2472, n=23+22
#     shapiro: p = 0.461, 0.129
# 	Updating plotParams from "cogVWRA/plotParams.txt"
# 	Removing 4 mice...
# ...

# %%
allFigures.fig3()
# Out:
# Irrad vs Sham: d = 1.62, t = 6.17, p=8.9594e-06, n=11+10
#     shapiro: p = 0.811, 0.863
# Irrad vs Sham: d = 1.46, t = 4.71, p=1.6794e-04, n=11+10
#     shapiro: p = 0.386, 0.508
# Irrad vs Sham: d = 1.02, t = 2.65, p=0.0167, n=11+10
#     shapiro: p = 0.934, 0.039
# Irrad vs Sham: d = 0.11, t = 0.24, p=0.8150, n=11+10
#     shapiro: p = 0.785, 0.643

# %%
allFigures.fig4()
# Out:
# mature BDNF: Irrad vs Sham: d = 0.48, u = 260.00, p=0.0334, n=30+26
# pro-BDNF: Irrad vs Sham: d = -0.03, u = 353.00, p=0.5487, n=30+26

# %%
allFigures.supp()
# Out:
# 	Updating plotParams from "cogVWRA/plotParams.txt"
# 	Removing 4 mice...
